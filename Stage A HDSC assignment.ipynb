# %%
import pandas as pd
FAO_df = pd.read_csv('/storage/emulated/0/d/FoodBalanceSheets_E_Africa_NOFLAG (2).csv', encoding= 'latin-1')
FAO_df.describe(include = "all")
# Out:
#            Area Code   Area     Item Code                     Item  \
# count   60943.000000  60943  60943.000000                    60943
# unique           NaN     49           NaN                      119
# top              NaN  Kenya           NaN  Milk - Excluding Butter
# freq             NaN   1560           NaN                     1262
# mean      134.265576    NaN   2687.176706                      NaN
# std        72.605709    NaN    146.055739                      NaN
# min         4.000000    NaN   2501.000000                      NaN
# 25%        74.000000    NaN   2562.000000                      NaN
# 50%       136.000000    NaN   2630.000000                      NaN
# 75%       195.000000    NaN   2775.000000                      NaN
# max       276.000000    NaN   2961.000000                      NaN
#
#         Element Code                   Element         Unit          Y2014  \
# count   60943.000000                     60943        60943   59354.000000
# ...

# %%
FAO_df.groupby('Item')['Item'].sum()
# Out:
# Item
# Alcohol, Non-Food      Alcohol, Non-FoodAlcohol, Non-FoodAlcohol, Non...
# Alcoholic Beverages    Alcoholic BeveragesAlcoholic BeveragesAlcoholi...
# Animal Products        Animal ProductsAnimal ProductsAnimal ProductsA...
# Animal fats            Animal fatsAnimal fatsAnimal fatsAnimal fatsAn...
# Apples and products    Apples and productsApples and productsApples a...
#                                              ...
# Vegetables, Other      Vegetables, OtherVegetables, OtherVegetables, ...
# Vegetal Products       Vegetal ProductsVegetal ProductsVegetal Produc...
# Wheat and products     Wheat and productsWheat and productsWheat and ...
# Wine                   WineWineWineWineWineWineWineWineWineWineWineWi...
# Yams                   YamsYamsYamsYamsYamsYamsYamsYamsYamsYamsYamsYa...
# Name: Item, Length: 119, dtype: object

# %%
FAO_df.isnull().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
grouped = FAO_df.groupby('Item').count()

# %%
print(grouped)
# Out:
#                      Area Code  Area  Item Code  Element Code  Element  Unit  \
# Item
# Alcohol, Non-Food          283   283        283           283      283   283
# Alcoholic Beverages        564   564        564           564      564   564
# Animal Products            135   135        135           135      135   135
# Animal fats                639   639        639           639      639   639
# Apples and products        517   517        517           517      517   517
# ...                        ...   ...        ...           ...      ...   ...
# Vegetables, Other          583   583        583           583      583   583
# Vegetal Products           135   135        135           135      135   135
# Wheat and products         653   653        653           653      653   653
# Wine                       497   497        497           497      497   497
# Yams                       383   383        383           383      383   383
#
# ...

# %%
print grouped["Animal fats"].sum()
# Out:
#   Input In [40]
#     print grouped["Animal fats"].count()
#           ^
# SyntaxError: invalid syntax
